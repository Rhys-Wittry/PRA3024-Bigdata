# %% [markdown]
# # <font color='deepskyblue'>Cosmology MCMC notebook </font>

# %% [markdown]
# ## <font color='deepskyblue'>Preliminaries</font>

# %%
# Install required packages (if not available on server)
try:
  import getdist
except:
  # !pip install getdist
  import getdist

# Load required packages
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy.integrate as integrate

# import pylab
import getdist, IPython, time
from numpy import random

# from IPython.display import Image
from getdist import plots, MCSamples, loadMCSamples

# just for printing! calculations should be performed with machine precision
# %precision 3

#import Pandas
import pandas as pd

# %% [markdown]
# <font color='tomato'>
# (NB: The equations you'll directly need to build your code are those $\boxed{\text{with a box around}}$)
# </font>
#
# ## <font color='deepskyblue'>The $\Lambda$CDM Model</font>
#
# The Lambda-Cold-Dark-Matter ($\Lambda$CDM) Model is our concordance cosmological model. It postulates a Universe that behaves according to **General Relativity**, filled with **baryons** (protons, neutrons - the stuff we and stars are made of!), **Cold Dark Matter (CDM)** and a **Cosmological Constant** $\Lambda$.
#
# The expansion of the Universe is best described in terms of the **scale factor** $a$ (the "radius" of the Universe, conventionally set to 1 today) and the **Hubble rate** $H$. While photons (light rays) travel in the expanding universe they get redshifted, and this redshift is directly related to the size of the Universe when the photon was emitted compared to today:
#
# $$ \frac{\lambda_{\rm obs}}{\lambda_{\rm em}} \equiv 1 + z_{\rm em} = \frac{1}{a_{\rm em}}$$
#
#
# In the $\Lambda$CDM model (and at late enough times), this additionally simplifies to
#
# $$
# \begin{gathered}
# \boxed{
# H^2 = H_0^2\left[\Omega_\Lambda + \Omega_m (1+z)^3 + \Omega_k (1+z)^2\right]
# }
# \\
# \boxed{
# \Omega_m + \Omega_\Lambda + \Omega_k = 1
# }
# \end{gathered}
# \tag{1}
# $$
#
# $H_0$ is the value of the Hubble rate *today*, and the parameters $\Omega_m$, $\Omega_\Lambda$ and $\Omega_k$ are dimensionless quantities indicating how much of the present expansion of the Universe is due to (non-relativistic) matter, cosmological constant $\Lambda$, and spatial curvature $k$. Note that the three $\Omega$'s are *not independent* (their sum is 1) and that we grouped together the contribution of baryons and CDM,
#
# $$
# \Omega_m = \Omega_{\rm CDM} + \Omega_{\rm b}
# $$
#
# and that we have evidence that independent evidence that $\Omega_b \approx 5$\%. NB: only $\Omega_m \geq 0$ makes physical sense, while in principle both $\Omega_\Lambda$ and $\Omega_k$ can be negative.
#
# The present Hubble rate is conventionally parametrised in terms of the dimensionless $h$:
#
# $$
# \boxed{
#   H_0 \equiv 100\,h\,\frac{\rm km}{\rm s\,Mpc}
# }
# \tag{2}
# $$
#
# where Mpc = Megaparsec and [parsec](https://en.wikipedia.org/wiki/Parsec) equals to about $3.26$ light years or $3.086 \cdot 10^{16}$ m.
#
# In essence, these equations give us the relation between *what exists in the Universe* and *how the Universe expanded*. Measure one, I can tell you the other. This is precisely what we aim to do!
#
# Time to define the function $H(z)$. Don't forget to include the useful parameters as arguments of the function, and to define `parsec`.

# %%
### Hubble rate
def Hubble(z, OmegaL, OmegaM, h):
    OmegaK = 1 - OmegaL - OmegaM
    H = (h*100) * np.sqrt (OmegaL + OmegaM * (1+z)**3 + OmegaK * (1+z)**2)
    return H

# %%
###Test Plot
OmegaL = 0.3
OmegaM = 0.7
h = 0.7

zList = np.arange(0,2,0.1)
HList = []
for z in zList:
    HList += [Hubble(z,OmegaL,OmegaM,h)]

plt.scatter(zList, HList)
plt.xlabel('z')
plt.ylabel('H(z)')
plt.show()

# %% [markdown]
# ## <font color='deepskyblue'>Supernovae Ia</font>
#
# In order to track the expansion of the Universe, we will look at Supernovae type Ia observations. SNIa are formed when a *white dwarf* accretes matter from a companion until it reaches a critical mass of about $1.44 M_\odot$ (solar masses), after which it explodes **at always the same luminosity** $L_{\rm SN}$. Therefore, the observed [magnitude](https://en.wikipedia.org/wiki/Magnitude_(astronomy)) is only a function of their [**luminosity distance**](https://en.wikipedia.org/wiki/Distance_measures_(cosmology)) from Earth, defined as the ratio of the intrinsic luminosity $L_{\rm SNIa}$ and the measured *surface brightness* $\Phi$ (energy per unit time per unit area)
#
# $$ d_L\equiv \frac{L_{\rm SN}}{4\pi \Phi} $$
#
# We can express the luminosity distance in terms of the Hubble rate:
#
# $$
# \boxed{
# d_L(z) = \frac{c}{H_0}(1+z) \times
# \begin{cases}
#     \cfrac{1}{\sqrt{\Omega_k}} \,\sinh\left(\sqrt{\Omega_k}\,D(z)\right) & \Omega_k > 0
#     \\[.5em]
#     D(z) & \Omega_k = 0
#     \\[.5em]
#     \cfrac{1}{\sqrt{-\Omega_k}} \,\sin\left(\sqrt{-\Omega_k}\,D(z)\right) & \Omega_k < 0
# \end{cases}
# \qquad\qquad
# D(z) \equiv H_0\int_0^z \frac{{\rm d}Z}{H(Z)}
# }
# \tag{3}
# $$
#
# where $c$ is the speed of light: $c \simeq 2.998 \cdot 10^{5}$ km/s.
#
# Clearly, there exists a relation between $d_L(z)$ and $H(z)$, so the luminosity distance is a useful measure of the Universe expansion history.
# In practice, however, the actual observable for [Supernovae Type Ia](https://en.wikipedia.org/wiki/Type_Ia_supernova) (or SNIa) is the [distance modulus](https://en.wikipedia.org/wiki/Distance_modulus) $\mu$, defined as the difference between the *apparent magnitude* $m$ and the *absolute magnitude* $M$:
#
# $$
# \boxed{
# \mu(z) \equiv m(z) - M \equiv 5 \log_{10} \frac{d_L(z)}{10\,\text{pc}}
# }
# \tag{4}
# $$
#
# We can create the function `dL(z, h, Omega_m, Omega_Lambda)`. You can also pass the function `Hubble` as an argument: `dL(z, Hubble, Omega_m, Omega_Lambda)`. Additionally, you can create $D(z)$ for your convenience.
#
# Note that you need to integrate the function $H(z)$, so write your own quick-and-easy numerical integrator, for example implementing the [trapezoidal rule](https://en.wikipedia.org/wiki/Trapezoidal_rule) or your favourite alternative, or [look up the pre-written methods](https://docs.scipy.org/doc/scipy/tutorial/integrate.html). Make sure it returns $d_L$ in parsecs and that it uses $H_0$ measured in units of 100 km/s/Mpc (which we called $h$).

# %%
c = 299792458 *10**-3
# Integrate 1/H from x = 0 to x = z
def D(z, OmegaL, OmegaM, H0): ###Hubble rate in km/s/Mpc
    D0 = H0 * integrate.quad(lambda x: 1/Hubble(x, OmegaL, OmegaM,H0),0,z)[0]
    return D0

def dL(z, OmegaL, OmegaM, H0): 
    OmegaK = 1. - OmegaL - OmegaM ## OmegaK
    Dz = D(z,OmegaL,OmegaM,H0)## co-moving coordinates
    
    
    ###Luminosity distance equations 3 different situaions 
    if(OmegaK > 0):
        dL = 1 / np.sqrt(OmegaK) * np.sinh(np.sqrt(OmegaK) * Dz)
    elif(OmegaK == 0):
        dL = Dz
    elif(OmegaK < 0):
        dL = 1 / np.sqrt(-OmegaK) * np.sin(np.sqrt(-OmegaK) * Dz)
        
    return 10.**4 * c /H0 * (1+z) * dL ##finishes the eqations

# %%
###graph test

OmegaL = 0.3
OmegaM = 0.7
H0 = 0.7

zList = np.arange(0,1.4,0.1)
dLList = []
for z in zList:
    dLList += [dL(z,OmegaL,OmegaM,H0)]

plt.scatter(zList, dLList)
plt.xlabel('z')
plt.ylabel('dL(z)')
plt.show()

# %%
def mu(z, OmegaL, OmegaM, H0): # distance modulus -- use eq.(4)
    Mu = 5 * np.log10(dL(z,OmegaL,OmegaM, H0)/10)
    return Mu

# %%
###Test
OmegaL = 0.3
OmegaM = 0.7
H0 = 0.7

zs = np.arange(0,1.4,0.1)
mus = []
for z in zs:
    mus += [mu(z,OmegaL,OmegaM,H0)]

plt.scatter(zs, mus)
plt.xlabel('z')
plt.ylabel('µ(z)')
plt.show()
# Out:
# /tmp/ipykernel_91/2664216482.py:2: RuntimeWarning: divide by zero encountered in log10
#   Mu = 5 * np.log10(dL(z,OmegaL,OmegaM, H0)/10)

# %% [markdown]
# ## <font color='deepskyblue'>The Union2.1 Compilation</font>
#
# Our source of data is from [Union2.1](http://supernova.lbl.gov/Union/). It is a collection of $580$ SNIa, each observation is comprised of redshift $z$
# Our goal today is to use SNIa measurements to constrain the parameters ($h, \Omega_\Lambda, \Omega_m$).
#
# In essence, we can calculate for each redshift the theoretical value of $\mu$ using this equation with the expression for $d_L(z)$ and our model of choice $H(z)$ -- note that we will need to perform a numerical integral! -- and compare this value with observations. A different model would amount to changing the theoretical value of $H(z)$.
#
# Let us start by importing and plotting the data:

# %%
dataloc = "http://supernova.lbl.gov/Union/figures/SCPUnion2.1_mu_vs_z.txt"

# Read in data as numpy array.
# Format is [name, redshift, magnitude, magnitude error, and another number?]
data = np.genfromtxt(dataloc)

# Print the first line as an example. (Note that genfromtxt turns the names into 'Not A Number')
display(data[0])
# Out:
# array([      nan, 2.849e-02, 3.535e+01, 2.239e-01, 1.284e-01])

# %%
# Extract the redshifts (zs), distance modulus (dist_mod) and magnitude estimated errors (err_dist_mod)
# Data are in columns, so we either slice it by columns: arr[:,n]...
zs = data[:,1] # redshift

# ...or transpose the array and then slice by row: arr_transposed[n]
distance_modulus = data.T[2] # distance modulus
error_distance_modulus = data.T[3] # errors on distance modulus = sigmas

# %%
# Let's look at the data, just for fun.
# We can look both at the raw data (distance modulus) or calculate the luminosity distance
# Note that Numpy allows us to manipulate whole arrays at once with something like:
#     array_2 = some_function_of(array_1)

# luminosity distance in Mpc
luminosity_distance_pc = 10. * 10.**(distance_modulus / 5.) ## in pc
luminosity_distance_Mpc = luminosity_distance_pc / 10.**6

##data frame
dataframe = pd.DataFrame({"redshift":zs,
                   "distance_modulus":distance_modulus,
                   "distance_modulus_error":error_distance_modulus,
                   "Luminosity distance pc":luminosity_distance_pc,
                   "luminosity_distance_Mpc":luminosity_distance_Mpc ,})
dataframe.describe()
# Out:
#          redshift  distance_modulus  distance_modulus_error  \
# count  580.000000        580.000000              580.000000
# mean     0.361631         40.028495                0.222955
# std      0.327353          3.195595                0.126012
# min      0.015000         33.824609                0.084144
# 25%      0.054550         36.920249                0.151396
# 50%      0.294028         40.884198                0.189029
# 75%      0.551700         42.517637                0.241556
# max      1.414000         45.410744                1.006812
#
#        Luminosity distance pc  luminosity_distance_Mpc
# count            5.800000e+02               580.000000
# mean             2.209307e+09              2209.306847
# std              2.317339e+09              2317.338603
# min              5.819984e+07                58.199838
# 25%              2.422198e+08               242.219796
# 50%              1.502674e+09              1502.674447
# 75%              3.188077e+09              3188.076719
# max              1.208228e+10             12082.277932

# %%
# Recommendation: you might want to try your functions here, and check that for Omega_m = 0.3 and Omega_L = 0.7 you get a decent match to the data (h =0.7)
# %matplotlib inline

# Plot distance modulus versus redshift (original data)
plt.xlabel("redshift")
plt.ylabel("distance modulus")

sorted_data = data[data[:,1].argsort()] ###thx lorenzo

plt.plot(sorted_data[:,1], sorted_data[:,2])

plt.figure(figsize=(10,7))
plt.xlabel("redshift")
plt.ylabel("distance modulus")
plt.plot(sorted_data[:,1], sorted_data[:,2])
plt.errorbar(zs, distance_modulus, yerr=data[:,3], fmt='x', markersize='2', color='k', ecolor='black')
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# ## <font color='deepskyblue'>Bayes' Theorem: Likelihood, Prior, Posterior (and Evidence...)</font>
#
# The **conditional probability of A given that B is true** is denoted with $P(A|B)$ (read: *probability of A given B*).
# Did A happen? Then B has probability $P(B|A)$ of happening.
#
# [**Bayes' Theorem**](https://en.wikipedia.org/wiki/Bayes%27_theorem) is simply a reflection of the symmetry of the concept of joint probability:
#
# $$
# P(A|B)P(B) = P(B|A)P(A)
# $$
#
# In physics, our goal is often to determine how likely the values of some parameters $\theta$ are, given how well they reproduce the data $D$.
# We write Bayes' theorem in the following equivalent form:
#
# $$
# P(\theta | D) = \frac{P(D|\theta)P(\theta)}{P(D)}
# $$
#
# The various terms conventionally take the names:
#
# $$
# \begin{aligned}
# P(\theta | D) & && \text{Posterior}
# \\
# P(D | \theta)& && \text{Likelihood}
# \\
# P(\theta) & && \text{Prior}
# \\
# P(D) & && \text{Evidence}
# \end{aligned}
# $$
#
# ### <font color='deepskyblue'>Prior</font>
#
# The *prior* quantifies our degree of prior belief in the model parameters. It can contain the results of previous experiments, or theoretical considerations (for instance, that certain parameters cannot be negative, etc.).
#
# We can have *strong priors* about something - the Sun still existing at night, see the comic below - or not.
# When we do *not* have compelling prior knowledge about a parameter, we generally use a *non-informative* prior probability distribution, most often related to the [uniform distribution](https://en.wikipedia.org/wiki/Continuous_uniform_distribution)
#
# $$
# \begin{aligned}
#     \text{Uniform} & && \theta \in \text{Uniform}[\theta_{\rm min}, \theta_{\rm max}]
#     \\
#     \text{Log Uniform} & && \log\theta \in \text{Uniform}[\log\theta_{\rm min}, \log\theta_{\rm max}]
# \end{aligned}
# $$
#
# You may sometimes hear that "the prior doesn't matter". While this is not strictly true, it is however true that in many instances the *likelihood* depends more dramatically on the parameters and will have a dominating contribution to the posterior. You are more than welcome to try different priors for the model parameters and see if and how your results change.
#
# ### <font color='deepskyblue'>Likelihood</font>
#
# The measure of how well our model reproduces the data is the **likelihood** $\mathcal L$. For normal (=Gaussian), uncorrelated data $\mu_i$ with errors $\sigma_i$ ($i = \{1,580\}$), the likelihood is related to the famous [**chi-squared**](https://en.wikipedia.org/wiki/Chi-square_distribution) via
#
# $$
# P(D | \theta) \equiv \mathcal L = \exp\left(-\frac{\chi^2}{2}\right)
# \qquad
# \qquad
# \boxed{
# \chi^2 \equiv \sum_{i=1}^{580} \frac{\left(\mu_i^{(\rm theor)} - \mu_i^{(\rm obs)}\right)^2}{\sigma_i^2}
# }
# \tag{5}
# $$
#
# A *high likelihood* corresponds to a *low chi squared*.
#
# In principle, we could attack the problem brute-force: create a grid of values for $h$, $\Omega_m$, $\Omega_\Lambda$, calculate the likelihood for each combination, and create a profile for the likelihood.
#
# In practical cases, however, this is not only sub-optimal but sometimes **impossible**. Think of complicated models with 20+ free parameters (this is not unheard of, by the way). Even a very coarse grained grid of 100 values for each parameter would result in more than $10^{40}$ (!!!) different parameter combination to be tested. You can probably understand why this is undesirable.
#
# ### <font color='deepskyblue'>Evidence</font>
#
# This is the tricky bit. The evidence, which is "*the probability of observing certain data*", is not something that is easy to evaluate or interpret. This looks like a serious limitation to finding the:
#
#
# ### <font color='deepskyblue'>Posterior</font>
#
# What does the data tell us about the model parameters? The answer is the *posterior probability distribution*, often (but not necessarily) expressed as (average $\pm$ standard deviation)
#
# $$
# \theta_i = \bar\theta_i \pm \sigma_i
# $$
#
# In other words, the posterior tells us how likely it is for the model parameters to have certain values, *given that we observe the data* $D$.
#
# *This is the final goal of our analysis!*
#
# <br>
#
# ![title](http://1.bp.blogspot.com/-tTx4HDejSww/ULcTeK9_V_I/AAAAAAAAA8g/PCYOH-eXGbk/s1600/frequentists_vs_bayesians.png)
# ![title](https://i.redd.it/5r0hwixt0m931.jpg)

# %% [markdown]
# ## <font color='deepskyblue'>Markov-Chain Monte Carlo</font>
#
# Markov-Chain Monte Carlo techniques are a class of methods to sample a probability distribution $P(x)$ - in our case $P(\theta | D)$ - provided that we can calculate a density $\mathcal F(x)$ **that is proportional to it** - in our case $P(\theta)P(D|\theta)$ = likelihood $\times$ prior. Among these, a very popular one is the [**Metropolis-Hastings**](https://en.wikipedia.org/wiki/Metropolis%E2%80%93Hastings_algorithm) algorithm, which is what we will use.
#
# Schematically, the algorithm works as follows:
# * Start with an $n$-tuple of parameters $\theta_{\rm old} = \{\theta_1, \theta_2, \dots\}_{\rm old}$ (in our case $\theta = \{h,\Omega_m,\Omega_\Lambda\}$) and calculate the $\mathcal F_{\rm old}$
# * Propose a new set of parameters $\theta_{\rm prop}$, calculate the new corresponding $\mathcal F_{\rm prop}$. How you propose the new parameters is not essential as long as the probability of going from one set of parameters to the next is the same as the inverse: $P(\theta_a \to \theta_b) = P(\theta_b \to \theta_a)$. For this, we normally take Gaussian displacements with some (relatively small) standard deviation.
# * Compare the new and old likelihoods-priors:
#     * If $\mathcal F_{\rm prop} > \mathcal F_{\rm old}$, accept the step: $\theta_{\rm new} = \theta_{\rm prop}$
#     * Otherwise, accept with probability $P_{\rm accept} = \mathcal F_{\rm prop}/\mathcal F_{\rm old}$
# * If accepted, $\theta_{\rm new} = \theta_{\rm prop}$ and record the step; otherwise, $\theta_{\rm new} = \theta_{\rm old}$ (no re-recording)
# * Update $\theta_{\rm old} = \theta_{\rm new}$
# * Repeat
#
# The MC chain keeps going until the desired number of steps or, ideally, when a suitable convergence test, like for example the [Gelman-Rubin test](https://bookdown.org/rdpeng/advstatcomp/monitoring-convergence.html), is satisfied.
# Today we will just set a limit to the total number of steps, but please feel free to implement and test your favourite convergence test!
#
# Looking at equation (5), you can convince yourself that
# $$
# \frac{\mathcal L_a}{\mathcal L_b} = \exp\left(\frac{\chi_b^2 - \chi_a^2}{2}\right)
# $$
#
# (This is useful because $\chi^2$ can be large, so we want to avoid the likelihoods evaluating to `0.` -- computers don't like dividing by zero, unfortunately)
#
#
# * <font color="deepskyblue"> Start with an $n$-tuple of parameters $\theta_{\rm old} = \{\theta_1, \theta_2, \dots\}_{\rm old}$ (in our case $\theta = \{h,\Omega_m,\Omega_\Lambda\}$) and the corresponding chi squared $\chi_{\rm old}^2$ (to be clear, for us this implies calculating a series of 580 integrals and comparing each with the observed values) </font>
# * <font color="deepskyblue"> Propose new parameters $\theta_{\rm prop}$ and calculate the corresponding chi squared $\chi_{\rm prop}^2$</font>
# * <font color="deepskyblue"> Draw a random number $r \in [0,1]$</font>
# * <font color="deepskyblue"> Accept the step if
# $$
# r < \exp\left(\frac{\chi_{\rm old}^2 - \chi_{\rm prop}^2}{2}\right) \frac{P(\theta)_{\rm prop}}{P(\theta)_{\rm old}}
# $$</font>
#     * <font color="deepskyblue"> If accepted, update $\theta_{\rm old} = \theta_{\rm prop}$</font>
#     * <font color="deepskyblue">If you want, you can keep a record of the best fit (lowest $\chi^2$), but this is not the specific purpose of MCMC! We are exploring the parameter space and sampling a _posterior distribution_, not just finding the best fit</font>
# * <font color="deepskyblue"> Record the step - including **re-recording** if the step was not accepted! </font>
# * <font color="deepskyblue"> Repeat</font>

# %%
### vectorize for speed
function = np.vectorize(mu)
### new function based on redshift for more speed
mu_vec = lambda h, OmegaM, OmegaL: function(dataframe['redshift'], h,OmegaM,OmegaL)

###Chi2 function    
def chi2(h, OmegaM, OmegaL):  
    return np.sum(np.square(np.subtract(mu_vec(h,OmegaM, OmegaL),dataframe['distance_modulus']))/(np.square(dataframe['distance_modulus_error'])))

### Generate some new values to check
def new_parameters(h, OmegaM, OmegaL):
    new_h = np.random.normal(h, 0.01)
    new_OmegaM = np.random.normal(OmegaM, 0.01)
    new_OmegaL = np.random.normal(OmegaL, 0.01)
    return np.array([new_h, new_OmegaM, new_OmegaL])


#Accept reject function
def accept_move(chi2current, chi2New):  
    
    r = np.random.uniform(0,1)

    if chi2New < chi2current:                            ### new chi2 > old chi2 means accept
        return True
    elif r <= min(1,np.exp(-(chi2New - chi2current)/2)) :  ### I was told to do this by a friend but idk why
        return True
    else:                                                ### all else is false and is rejected
        return False

### list making
chain = []
accepted = []
rejected = []

n = 0 ## step number counter

N_steps = 600 ### total step count (>= 5000 was suggested)

burn_in = 15 ##burn in of a few steps so that things run smooth
theta0 = np.array([0.5, 0.5, 0.5]) ### initeal guess values for h omegaM and omegaL

filename = "MC_Chain_SNIa.dat" ###this name works for me

chi2current=chi2(*theta0) #adding initial parameters to chi2
with open(filename, 'w') as f:
    f.write("h\tOmega_M\tOmega_L\tOmegaK\tchi2\t")
    while n < N_steps:
        print(f"step {n}/{N_steps}")
        
        thetaNew = new_parameters(*theta0) ###random change addition
        
        chi2New = chi2(*thetaNew)
       
        if accept_move(chi2current,chi2New): ### accept or reject function
            
            theta0 = thetaNew ### yeay new values that are nice
            
            chi2current = chi2New  ### change the chi2 testing value for future tests
            print('yeay a good step')
            if n>= burn_in:  ### record if past the burn in
                f.write(f"\n{theta0[0]}\t{theta0[1]}\t{theta0[2]}\t{1-theta0[1]-theta0[2]}\t{chi2current}\t")
                chain.append(theta0)
            accepted.append(chi2New)
        else:
            rejected.append(chi2New)
       
        n += 1 ### count +1 so that the loop will end at the end of the steps
# Out:
# step 0/600
# yeay a good step
# step 1/600
# step 2/600
# step 3/600
# step 4/600
# yeay a good step
# step 5/600
# yeay a good step
# step 6/600
# step 7/600
# yeay a good step
# step 8/600
# step 9/600
# yeay a good step
# step 10/600
# yeay a good step
# step 11/600
# yeay a good step
# step 12/600
# yeay a good step
# step 13/600
# yeay a good step
# step 14/600
# step 15/600
# step 16/600
# yeay a good step
# step 17/600
# yeay a good step
# step 18/600
# step 19/600
# yeay a good step
# step 20/600
# step 21/600
# yeay a good step
# step 22/600
# yeay a good step
# step 23/600
# yeay a good step
# step 24/600
# step 25/600
# yeay a good step
# step 26/600
# step 27/600
# yeay a good step
# step 28/600
# yeay a good step
# step 29/600
# step 30/600
# step 31/600
# yeay a good step
# step 32/600
# step 33/600
# yeay a good step
# step 34/600
# step 35/600
# yeay a good step
# step 36/600
# yeay a good step
# step 37/600
# yeay a good step
# step 38/600
# yeay a good step
# step 39/600
# step 40/600
# yeay a good step
# step 41/600
# step 42/600
# step 43/600
# yeay a good step
# step 44/600
# step 45/600
# yeay a good step
# step 46/600
# step 47/600
# yeay a good step
# step 48/600
# step 49/600
# yeay a good step
# step 50/600
# yeay a good step
# step 51/600
# yeay a good step
# step 52/600
# yeay a good step
# step 53/600
# yeay a good step
# step 54/600
# step 55/600
# step 56/600
# yeay a good step
# step 57/600
# yeay a good step
# step 58/600
# yeay a good step
# step 59/600
# yeay a good step
# step 60/600
# step 61/600
# step 62/600
# yeay a good step
# step 63/600
# yeay a good step
# step 64/600
# step 65/600
# yeay a good step
# step 66/600
# step 67/600
# step 68/600
# yeay a good step
# step 69/600
# yeay a good step
# step 70/600
# step 71/600
# yeay a good step
# step 72/600
# yeay a good step
# step 73/600
# yeay a good step
# step 74/600
# step 75/600
# yeay a good step
# step 76/600
# step 77/600
# step 78/600
# yeay a good step
# step 79/600
# step 80/600
# yeay a good step
# step 81/600
# step 82/600
# step 83/600
# step 84/600
# yeay a good step
# step 85/600
# yeay a good step
# step 86/600
# yeay a good step
# step 87/600
# step 88/600
# step 89/600
# yeay a good step
# step 90/600
# yeay a good step
# step 91/600
# yeay a good step
# step 92/600
# yeay a good step
# step 93/600
# yeay a good step
# step 94/600
# yeay a good step
# step 95/600
# yeay a good step
# step 96/600
# yeay a good step
# step 97/600
# step 98/600
# step 99/600
# step 100/600
# step 101/600
# step 102/600
# step 103/600
# yeay a good step
# step 104/600
# step 105/600
# step 106/600
# step 107/600
# step 108/600
# step 109/600
# step 110/600
# step 111/600
# step 112/600
# step 113/600
# step 114/600
# /tmp/ipykernel_91/2664216482.py:2: RuntimeWarning: invalid value encountered in log10
#   Mu = 5 * np.log10(dL(z,OmegaL,OmegaM, H0)/10)
# yeay a good step
# step 115/600
# step 116/600
# yeay a good step
# step 117/600
# yeay a good step
# step 118/600
# yeay a good step
# step 119/600
# yeay a good step
# step 120/600
# yeay a good step
# step 121/600
# yeay a good step
# step 122/600
# yeay a good step
# step 123/600
# yeay a good step
# step 124/600
# yeay a good step
# step 125/600
# yeay a good step
# step 126/600
# yeay a good step
# step 127/600
# yeay a good step
# step 128/600
# yeay a good step
# step 129/600
# yeay a good step
# step 130/600
# yeay a good step
# step 131/600
# yeay a good step
# step 132/600
# yeay a good step
# step 133/600
# yeay a good step
# step 134/600
# yeay a good step
# step 135/600
# yeay a good step
# step 136/600
# yeay a good step
# step 137/600
# yeay a good step
# step 138/600
# yeay a good step
# step 139/600
# yeay a good step
# step 140/600
# yeay a good step
# step 141/600
# yeay a good step
# step 142/600
# yeay a good step
# step 143/600
# yeay a good step
# step 144/600
# yeay a good step
# step 145/600
# yeay a good step
# step 146/600
# yeay a good step
# step 147/600
# yeay a good step
# step 148/600
# yeay a good step
# step 149/600
# yeay a good step
# step 150/600
# yeay a good step
# step 151/600
# yeay a good step
# step 152/600
# yeay a good step
# step 153/600
# yeay a good step
# step 154/600
# yeay a good step
# step 155/600
# yeay a good step
# step 156/600
# yeay a good step
# step 157/600
# yeay a good step
# step 158/600
# yeay a good step
# step 159/600
# yeay a good step
# step 160/600
# yeay a good step
# step 161/600
# yeay a good step
# step 162/600
# yeay a good step
# step 163/600
# yeay a good step
# step 164/600
# yeay a good step
# step 165/600
# yeay a good step
# step 166/600
# yeay a good step
# step 167/600
# yeay a good step
# step 168/600
# yeay a good step
# step 169/600
# yeay a good step
# step 170/600
# yeay a good step
# step 171/600
# yeay a good step
# step 172/600
# yeay a good step
# step 173/600
# yeay a good step
# step 174/600
# yeay a good step
# step 175/600
# yeay a good step
# step 176/600
# yeay a good step
# step 177/600
# yeay a good step
# step 178/600
# yeay a good step
# step 179/600
# yeay a good step
# step 180/600
# yeay a good step
# step 181/600
# yeay a good step
# step 182/600
# yeay a good step
# step 183/600
# yeay a good step
# step 184/600
# yeay a good step
# step 185/600
# yeay a good step
# step 186/600
# yeay a good step
# step 187/600
# yeay a good step
# step 188/600
# yeay a good step
# step 189/600
# step 190/600
# yeay a good step
# step 191/600
# yeay a good step
# step 192/600
# yeay a good step
# step 193/600
# yeay a good step
# step 194/600
# yeay a good step
# step 195/600
# yeay a good step
# step 196/600
# yeay a good step
# step 197/600
# yeay a good step
# step 198/600
# yeay a good step
# step 199/600
# yeay a good step
# step 200/600
# yeay a good step
# step 201/600
# yeay a good step
# step 202/600
# yeay a good step
# step 203/600
# yeay a good step
# step 204/600
# yeay a good step
# step 205/600
# yeay a good step
# step 206/600
# yeay a good step
# step 207/600
# yeay a good step
# step 208/600
# yeay a good step
# step 209/600
# yeay a good step
# step 210/600
# yeay a good step
# step 211/600
# yeay a good step
# step 212/600
# yeay a good step
# step 213/600
# yeay a good step
# step 214/600
# yeay a good step
# step 215/600
# yeay a good step
# step 216/600
# yeay a good step
# step 217/600
# yeay a good step
# step 218/600
# yeay a good step
# step 219/600
# yeay a good step
# step 220/600
# yeay a good step
# step 221/600
# yeay a good step
# step 222/600
# yeay a good step
# step 223/600
# yeay a good step
# step 224/600
# yeay a good step
# step 225/600
# yeay a good step
# step 226/600
# yeay a good step
# step 227/600
# yeay a good step
# step 228/600
# yeay a good step
# step 229/600
# yeay a good step
# step 230/600
# yeay a good step
# step 231/600
# yeay a good step
# step 232/600
# yeay a good step
# step 233/600
# yeay a good step
# step 234/600
# yeay a good step
# step 235/600
# yeay a good step
# step 236/600
# yeay a good step
# step 237/600
# yeay a good step
# step 238/600
# yeay a good step
# step 239/600
# yeay a good step
# step 240/600
# yeay a good step
# step 241/600
# yeay a good step
# step 242/600
# yeay a good step
# step 243/600
# yeay a good step
# step 244/600
# yeay a good step
# step 245/600
# yeay a good step
# step 246/600
# yeay a good step
# step 247/600
# yeay a good step
# step 248/600
# yeay a good step
# step 249/600
# yeay a good step
# step 250/600
# yeay a good step
# step 251/600
# yeay a good step
# step 252/600
# yeay a good step
# step 253/600
# yeay a good step
# step 254/600
# yeay a good step
# step 255/600
# yeay a good step
# step 256/600
# yeay a good step
# step 257/600
# yeay a good step
# step 258/600
# yeay a good step
# step 259/600
# yeay a good step
# step 260/600
# yeay a good step
# step 261/600
# yeay a good step
# step 262/600
# yeay a good step
# step 263/600
# yeay a good step
# step 264/600
# yeay a good step
# step 265/600
# yeay a good step
# step 266/600
# yeay a good step
# step 267/600
# yeay a good step
# step 268/600
# yeay a good step
# step 269/600
# yeay a good step
# step 270/600
# yeay a good step
# step 271/600
# yeay a good step
# step 272/600
# yeay a good step
# step 273/600
# yeay a good step
# step 274/600
# yeay a good step
# step 275/600
# yeay a good step
# step 276/600
# yeay a good step
# step 277/600
# yeay a good step
# step 278/600
# yeay a good step
# step 279/600
# yeay a good step
# step 280/600
# yeay a good step
# step 281/600
# yeay a good step
# step 282/600
# yeay a good step
# step 283/600
# yeay a good step
# step 284/600
# yeay a good step
# step 285/600
# yeay a good step
# step 286/600
# yeay a good step
# step 287/600
# yeay a good step
# step 288/600
# yeay a good step
# step 289/600
# yeay a good step
# step 290/600
# yeay a good step
# step 291/600
# yeay a good step
# step 292/600
# yeay a good step
# step 293/600
# yeay a good step
# step 294/600
# yeay a good step
# step 295/600
# yeay a good step
# step 296/600
# yeay a good step
# step 297/600
# yeay a good step
# step 298/600
# yeay a good step
# step 299/600
# yeay a good step
# step 300/600
# yeay a good step
# step 301/600
# yeay a good step
# step 302/600
# yeay a good step
# step 303/600
# yeay a good step
# step 304/600
# yeay a good step
# step 305/600
# yeay a good step
# step 306/600
# yeay a good step
# step 307/600
# yeay a good step
# step 308/600
# yeay a good step
# step 309/600
# yeay a good step
# step 310/600
# yeay a good step
# step 311/600
# yeay a good step
# step 312/600
# yeay a good step
# step 313/600
# yeay a good step
# step 314/600
# yeay a good step
# step 315/600
# yeay a good step
# step 316/600
# yeay a good step
# step 317/600
# yeay a good step
# step 318/600
# yeay a good step
# step 319/600
# yeay a good step
# step 320/600
# yeay a good step
# step 321/600
# yeay a good step
# step 322/600
# yeay a good step
# step 323/600
# yeay a good step
# step 324/600
# yeay a good step
# step 325/600
# yeay a good step
# step 326/600
# yeay a good step
# step 327/600
# yeay a good step
# step 328/600
# yeay a good step
# step 329/600
# yeay a good step
# step 330/600
# yeay a good step
# step 331/600
# yeay a good step
# step 332/600
# yeay a good step
# step 333/600
# yeay a good step
# step 334/600
# yeay a good step
# step 335/600
# yeay a good step
# step 336/600
# yeay a good step
# step 337/600
# yeay a good step
# step 338/600
# yeay a good step
# step 339/600
# yeay a good step
# step 340/600
# yeay a good step
# step 341/600
# yeay a good step
# step 342/600
# yeay a good step
# step 343/600
# yeay a good step
# step 344/600
# yeay a good step
# step 345/600
# yeay a good step
# step 346/600
# yeay a good step
# step 347/600
# yeay a good step
# step 348/600
# yeay a good step
# step 349/600
# yeay a good step
# step 350/600
# yeay a good step
# step 351/600
# yeay a good step
# step 352/600
# yeay a good step
# step 353/600
# yeay a good step
# step 354/600
# yeay a good step
# step 355/600
# yeay a good step
# step 356/600
# yeay a good step
# step 357/600
# yeay a good step
# step 358/600
# yeay a good step
# step 359/600
# yeay a good step
# step 360/600
# yeay a good step
# step 361/600
# yeay a good step
# step 362/600
# yeay a good step
# step 363/600
# yeay a good step
# step 364/600
# yeay a good step
# step 365/600
# yeay a good step
# step 366/600
# yeay a good step
# step 367/600
# yeay a good step
# step 368/600
# yeay a good step
# step 369/600
# yeay a good step
# step 370/600
# yeay a good step
# step 371/600
# yeay a good step
# step 372/600
# yeay a good step
# step 373/600
# yeay a good step
# step 374/600
# yeay a good step
# step 375/600
# yeay a good step
# step 376/600
# yeay a good step
# step 377/600
# yeay a good step
# step 378/600
# yeay a good step
# step 379/600
# yeay a good step
# step 380/600
# yeay a good step
# step 381/600
# yeay a good step
# step 382/600
# yeay a good step
# step 383/600
# yeay a good step
# step 384/600
# yeay a good step
# step 385/600
# yeay a good step
# step 386/600
# yeay a good step
# step 387/600
# yeay a good step
# step 388/600
# yeay a good step
# step 389/600
# yeay a good step
# step 390/600
# yeay a good step
# step 391/600
# yeay a good step
# step 392/600
# yeay a good step
# step 393/600
# yeay a good step
# step 394/600
# yeay a good step
# step 395/600
# yeay a good step
# step 396/600
# yeay a good step
# step 397/600
# yeay a good step
# step 398/600
# yeay a good step
# step 399/600
# yeay a good step
# step 400/600
# yeay a good step
# step 401/600
# yeay a good step
# step 402/600
# yeay a good step
# step 403/600
# yeay a good step
# step 404/600
# yeay a good step
# step 405/600
# yeay a good step
# step 406/600
# yeay a good step
# step 407/600
# yeay a good step
# step 408/600
# yeay a good step
# step 409/600
# yeay a good step
# step 410/600
# yeay a good step
# step 411/600
# yeay a good step
# step 412/600
# yeay a good step
# step 413/600
# yeay a good step
# step 414/600
# yeay a good step
# step 415/600
# yeay a good step
# step 416/600
# yeay a good step
# step 417/600
# yeay a good step
# step 418/600
# yeay a good step
# step 419/600
# yeay a good step
# step 420/600
# yeay a good step
# step 421/600
# yeay a good step
# step 422/600
# yeay a good step
# step 423/600
# yeay a good step
# step 424/600
# yeay a good step
# step 425/600
# yeay a good step
# step 426/600
# yeay a good step
# step 427/600
# yeay a good step
# step 428/600
# yeay a good step
# step 429/600
# yeay a good step
# step 430/600
# yeay a good step
# step 431/600
# yeay a good step
# step 432/600
# yeay a good step
# step 433/600
# yeay a good step
# step 434/600
# yeay a good step
# step 435/600
# yeay a good step
# step 436/600
# yeay a good step
# step 437/600
# yeay a good step
# step 438/600
# yeay a good step
# step 439/600
# yeay a good step
# step 440/600
# yeay a good step
# step 441/600
# yeay a good step
# step 442/600
# yeay a good step
# step 443/600
# yeay a good step
# step 444/600
# yeay a good step
# step 445/600
# yeay a good step
# step 446/600
# yeay a good step
# step 447/600
# yeay a good step
# step 448/600
# yeay a good step
# step 449/600
# yeay a good step
# step 450/600
# yeay a good step
# step 451/600
# yeay a good step
# step 452/600
# yeay a good step
# step 453/600
# yeay a good step
# step 454/600
# yeay a good step
# step 455/600
# yeay a good step
# step 456/600
# yeay a good step
# step 457/600
# yeay a good step
# step 458/600
# yeay a good step
# step 459/600
# yeay a good step
# step 460/600
# yeay a good step
# step 461/600
# yeay a good step
# step 462/600
# yeay a good step
# step 463/600
# yeay a good step
# step 464/600
# yeay a good step
# step 465/600
# yeay a good step
# step 466/600
# yeay a good step
# step 467/600
# yeay a good step
# step 468/600
# yeay a good step
# step 469/600
# yeay a good step
# step 470/600
# yeay a good step
# step 471/600
# yeay a good step
# step 472/600
# yeay a good step
# step 473/600
# yeay a good step
# step 474/600
# yeay a good step
# step 475/600
# yeay a good step
# step 476/600
# yeay a good step
# step 477/600
# yeay a good step
# step 478/600
# yeay a good step
# step 479/600
# yeay a good step
# step 480/600
# yeay a good step
# step 481/600
# yeay a good step
# step 482/600
# yeay a good step
# step 483/600
# yeay a good step
# step 484/600
# yeay a good step
# step 485/600
# yeay a good step
# step 486/600
# yeay a good step
# step 487/600
# yeay a good step
# step 488/600
# yeay a good step
# step 489/600
# yeay a good step
# step 490/600
# yeay a good step
# step 491/600
# yeay a good step
# step 492/600
# yeay a good step
# step 493/600
# yeay a good step
# step 494/600
# yeay a good step
# step 495/600
# yeay a good step
# step 496/600
# yeay a good step
# step 497/600
# yeay a good step
# step 498/600
# yeay a good step
# step 499/600
# yeay a good step
# step 500/600
# yeay a good step
# step 501/600
# yeay a good step
# step 502/600
# yeay a good step
# step 503/600
# yeay a good step
# step 504/600
# yeay a good step
# step 505/600
# yeay a good step
# step 506/600
# yeay a good step
# step 507/600
# yeay a good step
# step 508/600
# yeay a good step
# step 509/600
# yeay a good step
# step 510/600
# yeay a good step
# step 511/600
# yeay a good step
# step 512/600
# yeay a good step
# step 513/600
# yeay a good step
# step 514/600
# yeay a good step
# step 515/600
# yeay a good step
# step 516/600
# yeay a good step
# step 517/600
# yeay a good step
# step 518/600
# yeay a good step
# step 519/600
# yeay a good step
# step 520/600
# yeay a good step
# step 521/600
# yeay a good step
# step 522/600
# yeay a good step
# step 523/600
# yeay a good step
# step 524/600
# yeay a good step
# step 525/600
# yeay a good step
# step 526/600
# yeay a good step
# step 527/600
# yeay a good step
# step 528/600
# yeay a good step
# step 529/600
# yeay a good step
# step 530/600
# yeay a good step
# step 531/600
# yeay a good step
# step 532/600
# yeay a good step
# step 533/600
# yeay a good step
# step 534/600
# yeay a good step
# step 535/600
# yeay a good step
# step 536/600
# yeay a good step
# step 537/600
# yeay a good step
# step 538/600
# yeay a good step
# step 539/600
# yeay a good step
# step 540/600
# yeay a good step
# step 541/600
# yeay a good step
# step 542/600
# yeay a good step
# step 543/600
# yeay a good step
# step 544/600
# yeay a good step
# step 545/600
# yeay a good step
# step 546/600
# yeay a good step
# step 547/600
# yeay a good step
# step 548/600
# yeay a good step
# step 549/600
# yeay a good step
# step 550/600
# yeay a good step
# step 551/600
# yeay a good step
# step 552/600
# yeay a good step
# step 553/600
# yeay a good step
# step 554/600
# yeay a good step
# step 555/600
# yeay a good step
# step 556/600
# yeay a good step
# step 557/600
# yeay a good step
# step 558/600
# yeay a good step
# step 559/600
# yeay a good step
# step 560/600
# yeay a good step
# step 561/600
# yeay a good step
# step 562/600
# yeay a good step
# step 563/600
# yeay a good step
# step 564/600
# yeay a good step
# step 565/600
# yeay a good step
# step 566/600
# yeay a good step
# step 567/600
# yeay a good step
# step 568/600
# yeay a good step
# step 569/600
# yeay a good step
# step 570/600
# yeay a good step
# step 571/600
# yeay a good step
# step 572/600
# yeay a good step
# step 573/600
# yeay a good step
# step 574/600
# yeay a good step
# step 575/600
# yeay a good step
# step 576/600
# yeay a good step
# step 577/600
# yeay a good step
# step 578/600
# yeay a good step
# step 579/600
# yeay a good step
# step 580/600
# yeay a good step
# step 581/600
# yeay a good step
# step 582/600
# yeay a good step
# step 583/600
# yeay a good step
# step 584/600
# yeay a good step
# step 585/600
# yeay a good step
# step 586/600
# yeay a good step
# step 587/600
# yeay a good step
# step 588/600
# yeay a good step
# step 589/600
# yeay a good step
# step 590/600
# yeay a good step
# step 591/600
# yeay a good step
# step 592/600
# yeay a good step
# step 593/600
# yeay a good step
# step 594/600
# yeay a good step
# step 595/600
# yeay a good step
# step 596/600
# yeay a good step
# step 597/600
# yeay a good step
# step 598/600
# yeay a good step
# step 599/600
# yeay a good step

# %% [markdown]
# After completion of the programme, your MC chain will (*hopefully*) look something like this: (note the repeated entry!)
#
# `#Omega_m  Omega_L  h`
#
# `0.297     0.703    0.698`
#
# `0.285     0.715    0.701`
#
# `0.285     0.715    0.701`
#
# `0.288     0.712    0.699`
#
# `...`

# %% [markdown]
# ## <font color='deepskyblue'>Plotting: GetDist</font>
#
# We will do the plots with [`GetDist`](https://getdist.readthedocs.io/en/latest/plot_gallery.html).
#
# The plot gallery contains a lot of useful examples, you should be able to read them fairly easily and see which applies to your situation. Look for both (triangle) plots and for parameter estimation.
#
# Note that many `GetDist` functions require arguments of type `MCSamples`; make sure you convert your lists accordingly.
#
# <font color='deepskyblue'>
# Look at your results. Do you obtain $\Omega_\Lambda \neq 0$? To a high degree of significance?
#
# If yes, then my dear friend, you have **DISCOVERED THE ACCELERATED EXPANSION OF THE UNIVERSE AND WON THE NOBEL PRIZE IN PHYSICS 2011!**
# </font>

# %%
data = pd.read_csv("MC_Chain_SNIa.dat", sep="\t")

# %%
### burn in considered for the funnzies
h, OmegaM, OmegaL, OmegaK = data["h"], data["Omega_M"], data["Omega_L"], data["OmegaK"] ### adds the new data

# You can easily create new np.arrays that are functions of other np.arrays

# Let's define variable names and labels
my_labels = [r'h', r'\Omega_m', r'\Omega_\Lambda', r'\Omega_K']
my_names = ['h', 'OmegaM', 'OmegaL', 'OmegaK']
my_dim = len(my_names) # The number of variables we're plotting

my_samples = np.array([h, OmegaM, OmegaL, OmegaK]) # This creates a higher-dimensional array with all our data,
my_samples = np.transpose(np.reshape(my_samples,(my_dim,int(my_samples.size/my_dim)))) # and this reshapes it in a convenient form...
samples1 = MCSamples(samples = my_samples, labels = my_labels, names = my_names) # ... to create an "MCSamples" data type, which GetDist can use


conf_level = 0.9545 ### 2 sigma confidence cause I wanted to 

# This prints a table with the 1D posteriors (confidence levels)
for nam in my_names:
    print(round(samples1.confidence(nam,(1.-conf_level)/2.,upper=False),2), \
          " < ", nam , " < ", round(samples1.confidence(nam,(1.-conf_level)/2.,upper=True),2),\
          " at " , int(100*conf_level),"\b% CL")
print("\n\n")

#Triangle corner plot
j = plots.getSubplotPlotter(subplot_size=3)
j.settings.axes_labelsize = 22
j.settings.axes_fontsize = 16
j.triangle_plot(samples1, filled=True, title_limit=1)
# Out:
# Removed no burn in
# 0.49  <  h  <  0.73  at  95% CL
# 0.37  <  OmegaM  <  0.56  at  95% CL
# -0.5  <  OmegaL  <  0.32  at  95% CL
# 0.15  <  OmegaK  <  1.04  at  95% CL
# WARNING:root:2D kernel density bandwidth optimizer failed for h, OmegaL. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for h, OmegaK. Using fallback width: f(a) and f(b) must have different signs

# %% [markdown]
# ## <font color='deepskyblue'>Further Improvements</font>
#
# There are many ways in which you can improve your code and/or your data visualisation. Some ideas, in random order:
#
# * Modify your priors and compare your results. For instance:
#   * Change to log-flat priors for $h$ and/or $\Omega_m$, namely displace them in log-space instead of linear space:
#   $$
#   \log(h_{\rm new}) = \log(h_{\rm old}) + \delta
#   $$
#   where $\delta$ a random variable of mean 0
#   * Use priors from other cosmological probes, for example the [Planck 2018 results](https://arxiv.org/abs/1807.06209):
#   $$
#   \Omega_m = 0.315 \pm 0.007\,,~\dots
#   $$
# * Monitor acceptance ratio and $\chi^2$ as a function of step count
# * Implement a Gelman-Rubin (or alternative) convergence test
# * Change colours and other properties of your triangle plot
# * Re-plot the data with your theoretical fits: you can try both your best fit, and some $1\sigma$ "error bars"
# * Split your data in redshift bins and repeat the analysis for each bin individually.
# <br> _(What do you notice? Which redshift bins give us the most accurate detection of the cosmological parameters?)_

# %%
### I tried to changed the colors of the plot 
### instead i changed the searched for sigma confidence 
### I should have left the previous for show but to run all the code again will take to much time
